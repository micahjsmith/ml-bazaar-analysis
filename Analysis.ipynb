# %%
# %load_ext autoreload
# %aimport analysis
# %autoreload 1
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import analysis
from analysis import *

# %% [markdown]
# ## Run analyses

# %%
make_table_2()
# Out:
#                                        Tasks
# data_modality task_type
# graph         community_detection          2
#               graph_matching               9
#               link_prediction              1
#               vertex_nomination            1
# image         classification               5
#               regression                   1
# multi_table   classification               6
#               regression                   7
# single_table  classification             234
#               collaborative_filtering      4
#               regression                  87
#               time_series_forecasting     35
# text          classification              18
#               regression                   9
# timeseries    classification              37

# %%
make_figure_6()

# %%
make_figure_7()
# Out:
#                                                        min_score  \
# dataset
# 1491_one_hundred_plants_dataset_TRAIN                   0.000187
# 1567_poker_dataset_TRAIN                                0.000011
# 185_baseball_dataset_TRAIN                              0.027962
# 196_autoMpg_dataset_TRAIN                               8.419079
# 22_handgeometry_dataset_TRAIN                           0.348280
# 26_radon_seed_dataset_TRAIN                             0.025853
# 27_ws_dataset_TRAIN                                     0.011514
# 299_libras_dataset_TRAIN                                5.890561
# 30_personae_dataset_TRAIN                               0.000000
# 313_spectrometer_dataset_TRAIN                          0.000077
# 32_wikiqa_dataset_TRAIN                                 0.000000
# 38_sick_dataset_TRAIN                                   0.057758
# 4550_MiceProtein_dataset_TRAIN                          0.024441
# 49_facebook_dataset_TRAIN                               0.450383
# 534_cps_85_dataset_TRAIN                               19.106868
# 57_hd_dataset_TRAIN                                     0.008283
# 59_umls_dataset_TRAIN                                   0.446667
# 60_jester_dataset_TRAIN                                 3.982216
# 66_cn_dataset_TRAIN                                     0.239601
# 6_70_com_amazon_dataset_TRAIN                           0.000000
# 6_86_com_dataset_TRAIN                                  0.000000
# Airline-Sentiment-2-w-AA_dataset_TRAIN                  0.163849
# Coachella-2015-2-DFE_dataset_TRAIN                      0.045480
# Corporate-messaging-DFE_dataset_TRAIN                   0.013631
# LL0_1008_analcatdata_reviewer_dataset_TRAIN             0.300759
# LL0_1026_grub_damage_dataset_TRAIN                      0.265165
# LL0_1027_esl_dataset_TRAIN                              0.282183
# LL0_1028_swd_dataset_TRAIN                              0.376507
# LL0_1030_era_dataset_TRAIN                              2.450027
# LL0_1036_sylva_agnostic_dataset_TRAIN                   0.057991
# ...                                                          ...
# kaggle_open_powerlifting_competition_equipment_...      0.130043
# kaggle_open_powerlifting_competition_genders_da...      0.872634
# loan_amounts_dataset_TRAIN                          95813.409683
# loan_status_dataset_TRAIN                               0.180544
# mnist_dataset_TRAIN                                     0.094367
# paper_reviews_evaluation_dataset_TRAIN                  1.282380
# paper_reviews_orientation_dataset_TRAIN                 0.900761
# primary-plutchik-wheel-DFE_dataset_TRAIN                0.013841
# progressive-tweet-sentiment_dataset_TRAIN               0.092496
# reddit_200k_removed_dataset_TRAIN                       0.000000
# reddit_200k_score_dataset_TRAIN                       352.341625
# retail_sales_binary_dataset_TRAIN                       0.000000
# retail_sales_multi_dataset_TRAIN                        0.281788
# retail_sales_total_dataset_TRAIN                     1400.964886
# smart-app-functionality-DFE_dataset_TRAIN               0.001278
# social_news_popularity_facebook_dataset_TRAIN         605.503442
# social_news_popularity_googleplus_dataset_TRAIN        17.882630
# social_news_popularity_headline_sentiment_datas...      0.136376
# social_news_popularity_linkedin_dataset_TRAIN         160.633635
# social_news_popularity_title_sentiment_dataset_...      0.135426
# socialmedia-disaster-tweets-DFE_dataset_TRAIN           0.174122
# text_emotion_dataset_TRAIN                              0.003156
# tweet_global_warming_dataset_TRAIN                      0.065448
# twitter-airline-sentiment_dataset_TRAIN                 0.163849
# twitter-hate-speech-classifier-DFE-a845520_data...      0.199727
# usps_dataset_TRAIN                                      0.080101
# uu1_datasmash_dataset_TRAIN                             0.197802
# uu3_world_development_indicators_dataset_TRAIN          0.653628
# uu4_SPECT_dataset_TRAIN                                 0.000000
# weather-agg-DFE_dataset_TRAIN                           0.044985
#
#                                                         max_score  \
# dataset
# 1491_one_hundred_plants_dataset_TRAIN                    0.779090
# 1567_poker_dataset_TRAIN                                 0.449262
# 185_baseball_dataset_TRAIN                               0.692317
# 196_autoMpg_dataset_TRAIN                              531.915471
# 22_handgeometry_dataset_TRAIN                            0.721904
# 26_radon_seed_dataset_TRAIN                              1.097086
# 27_ws_dataset_TRAIN                                      0.297066
# 299_libras_dataset_TRAIN                                66.890125
# 30_personae_dataset_TRAIN                                0.750288
# 313_spectrometer_dataset_TRAIN                           0.386849
# 32_wikiqa_dataset_TRAIN                                  0.101045
# 38_sick_dataset_TRAIN                                    0.952000
# 4550_MiceProtein_dataset_TRAIN                           1.000000
# 49_facebook_dataset_TRAIN                                0.649180
# 534_cps_85_dataset_TRAIN                                96.288782
# 57_hd_dataset_TRAIN                                      0.878938
# 59_umls_dataset_TRAIN                                    0.882540
# 60_jester_dataset_TRAIN                                  5.037105
# 66_cn_dataset_TRAIN                                      0.427487
# 6_70_com_amazon_dataset_TRAIN                            0.817790
# 6_86_com_dataset_TRAIN                                   0.818360
# Airline-Sentiment-2-w-AA_dataset_TRAIN                   0.905396
# Coachella-2015-2-DFE_dataset_TRAIN                       0.596880
# Corporate-messaging-DFE_dataset_TRAIN                    0.832389
# LL0_1008_analcatdata_reviewer_dataset_TRAIN              0.693130
# LL0_1026_grub_damage_dataset_TRAIN                       0.792628
# LL0_1027_esl_dataset_TRAIN                              24.546264
# LL0_1028_swd_dataset_TRAIN                               9.401498
# LL0_1030_era_dataset_TRAIN                              13.758725
# LL0_1036_sylva_agnostic_dataset_TRAIN                    0.977528
# ...                                                           ...
# kaggle_open_powerlifting_competition_equipment_...       0.640794
# kaggle_open_powerlifting_competition_genders_da...       0.997923
# loan_amounts_dataset_TRAIN                          163110.561738
# loan_status_dataset_TRAIN                                0.558275
# mnist_dataset_TRAIN                                      0.976867
# paper_reviews_evaluation_dataset_TRAIN                   1.523338
# paper_reviews_orientation_dataset_TRAIN                  1.062993
# primary-plutchik-wheel-DFE_dataset_TRAIN                 0.270318
# progressive-tweet-sentiment_dataset_TRAIN                0.676370
# reddit_200k_removed_dataset_TRAIN                        0.587892
# reddit_200k_score_dataset_TRAIN                        354.844014
# retail_sales_binary_dataset_TRAIN                        0.482057
# retail_sales_multi_dataset_TRAIN                         0.568886
# retail_sales_total_dataset_TRAIN                      1796.750951
# smart-app-functionality-DFE_dataset_TRAIN                0.630648
# social_news_popularity_facebook_dataset_TRAIN          627.556821
# social_news_popularity_googleplus_dataset_TRAIN         18.412021
# social_news_popularity_headline_sentiment_datas...       0.141375
# social_news_popularity_linkedin_dataset_TRAIN          162.255493
# social_news_popularity_title_sentiment_dataset_...       0.136484
# socialmedia-disaster-tweets-DFE_dataset_TRAIN            0.704825
# text_emotion_dataset_TRAIN                               0.308281
# tweet_global_warming_dataset_TRAIN                       0.855715
# twitter-airline-sentiment_dataset_TRAIN                  0.892076
# twitter-hate-speech-classifier-DFE-a845520_data...       0.710949
# usps_dataset_TRAIN                                       0.976409
# uu1_datasmash_dataset_TRAIN                              1.000000
# uu3_world_development_indicators_dataset_TRAIN          11.597935
# uu4_SPECT_dataset_TRAIN                                  0.926448
# weather-agg-DFE_dataset_TRAIN                            0.609923
#
#                                                     default_score  \
# dataset
# 1491_one_hundred_plants_dataset_TRAIN                    0.420287
# 1567_poker_dataset_TRAIN                                 0.121985
# 185_baseball_dataset_TRAIN                               0.501456
# 196_autoMpg_dataset_TRAIN                               11.228723
# 22_handgeometry_dataset_TRAIN                            0.384875
# 26_radon_seed_dataset_TRAIN                              0.128230
# 27_ws_dataset_TRAIN                                      0.137002
# 299_libras_dataset_TRAIN                                 8.710325
# 30_personae_dataset_TRAIN                                0.716005
# 313_spectrometer_dataset_TRAIN                           0.273489
# 32_wikiqa_dataset_TRAIN                                  0.000000
# 38_sick_dataset_TRAIN                                    0.754116
# 4550_MiceProtein_dataset_TRAIN                           1.000000
# 49_facebook_dataset_TRAIN                                0.622650
# 534_cps_85_dataset_TRAIN                                20.691360
# 57_hd_dataset_TRAIN                                      0.639237
# 59_umls_dataset_TRAIN                                    0.823889
# 60_jester_dataset_TRAIN                                  4.828914
# 66_cn_dataset_TRAIN                                      0.381991
# 6_70_com_amazon_dataset_TRAIN                            0.817790
# 6_86_com_dataset_TRAIN                                   0.818360
# Airline-Sentiment-2-w-AA_dataset_TRAIN                   0.766478
# Coachella-2015-2-DFE_dataset_TRAIN                       0.596230
# Corporate-messaging-DFE_dataset_TRAIN                    0.698890
# LL0_1008_analcatdata_reviewer_dataset_TRAIN              0.598721
# LL0_1026_grub_damage_dataset_TRAIN                       0.661619
# LL0_1027_esl_dataset_TRAIN                               0.431567
# LL0_1028_swd_dataset_TRAIN                               0.413399
# LL0_1030_era_dataset_TRAIN                               2.551256
# LL0_1036_sylva_agnostic_dataset_TRAIN                    0.777890
# ...                                                           ...
# kaggle_open_powerlifting_competition_equipment_...       0.576363
# kaggle_open_powerlifting_competition_genders_da...       0.992302
# loan_amounts_dataset_TRAIN                          122052.507741
# loan_status_dataset_TRAIN                                0.508225
# mnist_dataset_TRAIN                                      0.701726
# paper_reviews_evaluation_dataset_TRAIN                   1.490923
# paper_reviews_orientation_dataset_TRAIN                  1.034351
# primary-plutchik-wheel-DFE_dataset_TRAIN                 0.228252
# progressive-tweet-sentiment_dataset_TRAIN                0.545900
# reddit_200k_removed_dataset_TRAIN                        0.358989
# reddit_200k_score_dataset_TRAIN                        352.408988
# retail_sales_binary_dataset_TRAIN                        0.000000
# retail_sales_multi_dataset_TRAIN                         0.281788
# retail_sales_total_dataset_TRAIN                      1760.158286
# smart-app-functionality-DFE_dataset_TRAIN                0.513285
# social_news_popularity_facebook_dataset_TRAIN          615.686824
# social_news_popularity_googleplus_dataset_TRAIN         17.906504
# social_news_popularity_headline_sentiment_datas...       0.141058
# social_news_popularity_linkedin_dataset_TRAIN          161.268357
# social_news_popularity_title_sentiment_dataset_...       0.136298
# socialmedia-disaster-tweets-DFE_dataset_TRAIN            0.639646
# text_emotion_dataset_TRAIN                               0.279281
# tweet_global_warming_dataset_TRAIN                       0.842811
# twitter-airline-sentiment_dataset_TRAIN                  0.765027
# twitter-hate-speech-classifier-DFE-a845520_data...       0.596105
# usps_dataset_TRAIN                                       0.776215
# uu1_datasmash_dataset_TRAIN                              1.000000
# uu3_world_development_indicators_dataset_TRAIN           3.908160
# uu4_SPECT_dataset_TRAIN                                  0.888166
# weather-agg-DFE_dataset_TRAIN                            0.301232
#
#                                                               sd  adjustment  \
# dataset
# 1491_one_hundred_plants_dataset_TRAIN                   0.250809           1
# 1567_poker_dataset_TRAIN                                0.058226           1
# 185_baseball_dataset_TRAIN                              0.151459           1
# 196_autoMpg_dataset_TRAIN                              20.821066          -1
# 22_handgeometry_dataset_TRAIN                           0.090626          -1
# 26_radon_seed_dataset_TRAIN                             0.306164          -1
# 27_ws_dataset_TRAIN                                     0.062080           1
# 299_libras_dataset_TRAIN                                4.452990          -1
# 30_personae_dataset_TRAIN                               0.134134           1
# 313_spectrometer_dataset_TRAIN                          0.132155           1
# 32_wikiqa_dataset_TRAIN                                 0.023861           1
# 38_sick_dataset_TRAIN                                   0.217482           1
# 4550_MiceProtein_dataset_TRAIN                          0.370136           1
# 49_facebook_dataset_TRAIN                               0.035866           1
# 534_cps_85_dataset_TRAIN                                4.474677          -1
# 57_hd_dataset_TRAIN                                     0.286330           1
# 59_umls_dataset_TRAIN                                   0.065085           1
# 60_jester_dataset_TRAIN                                 0.291423          -1
# 66_cn_dataset_TRAIN                                     0.016616           1
# 6_70_com_amazon_dataset_TRAIN                           0.196186           1
# 6_86_com_dataset_TRAIN                                  0.198228           1
# Airline-Sentiment-2-w-AA_dataset_TRAIN                  0.143781           1
# Coachella-2015-2-DFE_dataset_TRAIN                      0.182828           1
# Corporate-messaging-DFE_dataset_TRAIN                   0.209491           1
# LL0_1008_analcatdata_reviewer_dataset_TRAIN             0.108354           1
# LL0_1026_grub_damage_dataset_TRAIN                      0.122744           1
# LL0_1027_esl_dataset_TRAIN                              0.881708          -1
# LL0_1028_swd_dataset_TRAIN                              0.294272          -1
# LL0_1030_era_dataset_TRAIN                              0.588638          -1
# LL0_1036_sylva_agnostic_dataset_TRAIN                   0.225326           1
# ...                                                          ...         ...
# kaggle_open_powerlifting_competition_equipment_...      0.278155           1
# kaggle_open_powerlifting_competition_genders_da...      0.047019           1
# loan_amounts_dataset_TRAIN                          20682.607476          -1
# loan_status_dataset_TRAIN                               0.039201           1
# mnist_dataset_TRAIN                                     0.235292           1
# paper_reviews_evaluation_dataset_TRAIN                  0.062040          -1
# paper_reviews_orientation_dataset_TRAIN                 0.038998          -1
# primary-plutchik-wheel-DFE_dataset_TRAIN                0.078148           1
# progressive-tweet-sentiment_dataset_TRAIN               0.084729           1
# reddit_200k_removed_dataset_TRAIN                       0.246386           1
# reddit_200k_score_dataset_TRAIN                         1.341244          -1
# retail_sales_binary_dataset_TRAIN                       0.121763           1
# retail_sales_multi_dataset_TRAIN                        0.103962           1
# retail_sales_total_dataset_TRAIN                      103.255232          -1
# smart-app-functionality-DFE_dataset_TRAIN               0.203910           1
# social_news_popularity_facebook_dataset_TRAIN           7.202142          -1
# social_news_popularity_googleplus_dataset_TRAIN         0.231658          -1
# social_news_popularity_headline_sentiment_datas...      0.001413          -1
# social_news_popularity_linkedin_dataset_TRAIN           0.598857          -1
# social_news_popularity_title_sentiment_dataset_...      0.000225          -1
# socialmedia-disaster-tweets-DFE_dataset_TRAIN           0.069797           1
# text_emotion_dataset_TRAIN                              0.087195           1
# tweet_global_warming_dataset_TRAIN                      0.145864           1
# twitter-airline-sentiment_dataset_TRAIN                 0.156895           1
# twitter-hate-speech-classifier-DFE-a845520_data...      0.093860           1
# usps_dataset_TRAIN                                      0.332463           1
# uu1_datasmash_dataset_TRAIN                             0.307629           1
# uu3_world_development_indicators_dataset_TRAIN          4.278367          -1
# uu4_SPECT_dataset_TRAIN                                 0.064189           1
# weather-agg-DFE_dataset_TRAIN                           0.078862           1
#
#                                                       best_score     delta
# dataset
# 1491_one_hundred_plants_dataset_TRAIN                   0.779090  1.430583
# 1567_poker_dataset_TRAIN                                0.449262  5.620772
# 185_baseball_dataset_TRAIN                              0.692317  1.260150
# 196_autoMpg_dataset_TRAIN                               8.419079  0.134942
# 22_handgeometry_dataset_TRAIN                           0.348280  0.403805
# 26_radon_seed_dataset_TRAIN                             0.025853  0.334389
# 27_ws_dataset_TRAIN                                     0.297066  2.578325
# 299_libras_dataset_TRAIN                                5.890561  0.633229
# 30_personae_dataset_TRAIN                               0.750288  0.255593
# 313_spectrometer_dataset_TRAIN                          0.386849  0.857780
# 32_wikiqa_dataset_TRAIN                                 0.101045  4.234793
# 38_sick_dataset_TRAIN                                   0.952000  0.909886
# 4550_MiceProtein_dataset_TRAIN                          1.000000  0.000000
# 49_facebook_dataset_TRAIN                               0.649180  0.739704
# 534_cps_85_dataset_TRAIN                               19.106868  0.354102
# 57_hd_dataset_TRAIN                                     0.878938  0.837147
# 59_umls_dataset_TRAIN                                   0.882540  0.901143
# 60_jester_dataset_TRAIN                                 3.982216  2.905390
# 66_cn_dataset_TRAIN                                     0.427487  2.738120
# 6_70_com_amazon_dataset_TRAIN                           0.817790  0.000000
# 6_86_com_dataset_TRAIN                                  0.818360  0.000000
# Airline-Sentiment-2-w-AA_dataset_TRAIN                  0.905396  0.966177
# Coachella-2015-2-DFE_dataset_TRAIN                      0.596880  0.003555
# Corporate-messaging-DFE_dataset_TRAIN                   0.832389  0.637255
# LL0_1008_analcatdata_reviewer_dataset_TRAIN             0.693130  0.871299
# LL0_1026_grub_damage_dataset_TRAIN                      0.792628  1.067338
# LL0_1027_esl_dataset_TRAIN                              0.282183  0.169425
# LL0_1028_swd_dataset_TRAIN                              0.376507  0.125365
# LL0_1030_era_dataset_TRAIN                              2.450027  0.171971
# LL0_1036_sylva_agnostic_dataset_TRAIN                   0.977528  0.885998
# ...                                                          ...       ...
# kaggle_open_powerlifting_competition_equipment_...      0.640794  0.231638
# kaggle_open_powerlifting_competition_genders_da...      0.997923  0.119556
# loan_amounts_dataset_TRAIN                          95813.409683  1.268655
# loan_status_dataset_TRAIN                               0.558275  1.276746
# mnist_dataset_TRAIN                                     0.976867  1.169358
# paper_reviews_evaluation_dataset_TRAIN                  1.282380  3.361407
# paper_reviews_orientation_dataset_TRAIN                 0.900761  3.425526
# primary-plutchik-wheel-DFE_dataset_TRAIN                0.270318  0.538286
# progressive-tweet-sentiment_dataset_TRAIN               0.676370  1.539838
# reddit_200k_removed_dataset_TRAIN                       0.587892  0.929045
# reddit_200k_score_dataset_TRAIN                       352.341625  0.050224
# retail_sales_binary_dataset_TRAIN                       0.482057  3.958978
# retail_sales_multi_dataset_TRAIN                        0.568886  2.761561
# retail_sales_total_dataset_TRAIN                     1400.964886  3.478694
# smart-app-functionality-DFE_dataset_TRAIN               0.630648  0.575566
# social_news_popularity_facebook_dataset_TRAIN         605.503442  1.413938
# social_news_popularity_googleplus_dataset_TRAIN        17.882630  0.103061
# social_news_popularity_headline_sentiment_datas...      0.136376  3.314455
# social_news_popularity_linkedin_dataset_TRAIN         160.633635  1.059889
# social_news_popularity_title_sentiment_dataset_...      0.135426  3.867800
# socialmedia-disaster-tweets-DFE_dataset_TRAIN           0.704825  0.933825
# text_emotion_dataset_TRAIN                              0.308281  0.332578
# tweet_global_warming_dataset_TRAIN                      0.855715  0.088460
# twitter-airline-sentiment_dataset_TRAIN                 0.892076  0.809767
# twitter-hate-speech-classifier-DFE-a845520_data...      0.710949  1.223576
# usps_dataset_TRAIN                                      0.976409  0.602153
# uu1_datasmash_dataset_TRAIN                             1.000000  0.000000
# uu3_world_development_indicators_dataset_TRAIN          0.653628  0.760695
# uu4_SPECT_dataset_TRAIN                                 0.926448  0.596395
# weather-agg-DFE_dataset_TRAIN                           0.609923  3.914332
#
# [456 rows x 7 columns]

# %%
compute_total_pipelines()
# Out:
# '2553484 total pipelines evaluated'

# %%
compute_pipelines_second_VI()
# Out:
# 0.12649232305156313

# %%
compute_performance_vs_baseline_V_B()

# %%
compute_tuning_improvement_sds_VI_A()
# Out:
# 1.0599123055383604

# %%
compute_tuning_improvement_pct_of_tasks_VI_A()
# Out:
# 31.648351648351646

# %%
compute_npipelines_xgbrf_VI_B()
# Out:
#        pipelines
# RF        844286
# XGB      1019949
# total    1864235

# %%
compute_xgb_wins_pct_VI_B()
# Out:
#         wins   percent
# XGB    238.0  0.648501
# RF     129.0  0.351499
# total  367.0  1.000000

# %%
compute_npipelines_maternse_VI_C()
# Out:
#           pipelines
# SE           221536
# Matern52     209208
# total        430744

# %%
compute_matern_wins_pct_VI_C()
# Out:
#                  wins   percent
# GP-SE-EI        249.0  0.601449
# GP-Matern52-EI  165.0  0.398551
# total           414.0  1.000000
