# %%
import sys
sys.path.append('..')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import analysis
from analysis import *

# %% [markdown]
# ## Run analyses

# %%
make_table_3()
# Out:
#   0%|          | 0/476 [00:00<?, ?it/s]
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-effc5469c883> in <module>
# ----> 1 make_table_3()
#
# ~/workspace/ml-bazaar-analysis/analysis.py in make_table_3()
#     419
#     420 def make_table_3():
# --> 421     df = _load_task_characteristics_df()
#     422     df = df[['dataset_id', 'n', 'm', 'classes',
#     423              'du_compressed', 'du_inflated', 'size']]
#
# ~/workspace/ml-bazaar-analysis/analysis.py in _load_task_characteristics_df()
#     407             records = create_all_records()
#     408         except botocore.client.ClientError:
# --> 409             raise RuntimeError('task suite not currently accessible') from None
#     410         df = pd.DataFrame.from_records(records)
#     411         df.to_csv(path, sep='\t')
#
# RuntimeError: task suite not currently accessible

# %%
make_figure_4()
# Out:
#                  time                                                         \
#                 count       mean        std        min        25%        50%
# time_type
# abz_time         59.0   5.664189   6.062949   0.479307   1.039263   3.121628
# btb_gp_time      59.0   1.223472   6.596607   0.000839   0.020985   0.050460
# btb_time         59.0   0.095243   0.315168   0.001141   0.012032   0.022989
# io_time          59.0   0.242526   0.400887   0.023014   0.053081   0.077117
# mlblocks_time    59.0   2.093582  10.678184   0.012239   0.046854   0.066941
# primitives_time  59.0  90.680988  15.372593  21.447407  90.234247  96.150138
#
#
#                        75%        max
# time_type
# abz_time          9.322672  25.792295
# btb_gp_time       0.121094  49.497301
# btb_time          0.045809   2.243642
# io_time           0.232158   2.280624
# mlblocks_time     0.093718  59.416554
# primitives_time  98.296616  99.002045

# %%
make_figure_4()
# Out:
#                  time                                                         \
#                 count       mean        std        min        25%        50%
# time_type
# abz_time         59.0   5.664189   6.062949   0.479307   1.039263   3.121628
# btb_gp_time      59.0   1.223472   6.596607   0.000839   0.020985   0.050460
# btb_time         59.0   0.095243   0.315168   0.001141   0.012032   0.022989
# io_time          59.0   0.242526   0.400887   0.023014   0.053081   0.077117
# mlblocks_time    59.0   2.093582  10.678184   0.012239   0.046854   0.066941
# primitives_time  59.0  90.680988  15.372593  21.447407  90.234247  96.150138
#
#
#                        75%        max
# time_type
# abz_time          9.322672  25.792295
# btb_gp_time       0.121094  49.497301
# btb_time          0.045809   2.243642
# io_time           0.232158   2.280624
# mlblocks_time     0.093718  59.416554
# primitives_time  98.296616  99.002045

# %%
make_figure_x()

# %%
make_figure_5()
# Out:
#                                                        min_score  \
# dataset
# 1491_one_hundred_plants_dataset_TRAIN                   0.000187
# 1567_poker_dataset_TRAIN                                0.000011
# 185_baseball_dataset_TRAIN                              0.027962
# 196_autoMpg_dataset_TRAIN                               8.419079
# 22_handgeometry_dataset_TRAIN                           0.348280
# 26_radon_seed_dataset_TRAIN                             0.025853
# 27_ws_dataset_TRAIN                                     0.011514
# 299_libras_dataset_TRAIN                                5.890561
# 30_personae_dataset_TRAIN                               0.000000
# 313_spectrometer_dataset_TRAIN                          0.000077
# 32_wikiqa_dataset_TRAIN                                 0.000000
# 38_sick_dataset_TRAIN                                   0.057758
# 4550_MiceProtein_dataset_TRAIN                          0.024441
# ...

# %%
compute_total_pipelines()
# Out:
# '2553484 total pipelines evaluated'

# %%
compute_pipelines_second()
# Out:
# 0.12649232305156313

# %%
compute_performance_vs_baseline()

# %%
compute_tuning_improvement_sds_5_4()
# Out:
# 1.0599123055383604

# %%
compute_tuning_improvement_pct_of_tasks_5_4()
# Out:
# 31.648351648351646

# %%
compute_npipelines_xgbrf_5_6()
# Out:
#        pipelines
# RF        844286
# XGB      1019949
# total    1864235

# %%
compute_xgb_wins_pct_5_6()
# Out:
#         wins   percent
# XGB    238.0  0.648501
# RF     129.0  0.351499
# total  367.0  1.000000

# %%
compute_npipelines_maternse_5_7()
# Out:
#           pipelines
# SE           221536
# Matern52     209208
# total        430744

# %%
compute_matern_wins_pct_5_7()
# Out:
#                  wins   percent
# GP-SE-EI        249.0  0.601449
# GP-Matern52-EI  165.0  0.398551
# total           414.0  1.000000
